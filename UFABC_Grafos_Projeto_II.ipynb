# %% [markdown]
# <a href="https://colab.research.google.com/github/artrizzo/Python/blob/main/UFABC_Grafos_Projeto_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **PROJETO PRÁTICO**
# ---

# %% [markdown]
# **Modelagem com Redes**

# %% [markdown]
# O **Projeto Prático** da disciplina de **Comunicação e Redes** consistirá da coleta, preparação dos dados e análise de uma rede em torno de um tema escolhido pela equipe. A escolha do tema é livre. Entretanto, a rede a ser analisada deve ter **no mínimo** 50 vértices e 100 arestas.

# %% [markdown]
# O projeto deve ser implementado usando a linguagem Python e a biblioteca **NetworkX**. A biblioteca **AlgorithmX** também pode ser usada.

# %%
from networkx.algorithms.cuts import edge_expansion
import networkx as nx
import matplotlib.pyplot as plt

projeto = nx.Graph()
projeto.add_nodes_from(['AC','AED','Aero I','AIMRT','ATRI','BCE','BC','BD','BECM','Bioquimica','BMT','CB','CDD','CGEO','CG','Com I','CP','CR','CTS','DA','Demo','Din I','DRGR','ECA','EDP','EDS','EI','EP','EPIE','Espec','ET','Ética','FA','FHAL','FP','FPP','FT','FUV','FV II','GPO','GP','GPIR','HAH','HEG','HFC','HFME','HFMO','HTM','IA','IDC','IED','IEDO','IN','InA','IPP','LB','LF II','MacroE II','MF I','MH II','MicroB','MP','MPK','Neuro','OPGM','PE','PEB II','PEBC','PECM','PEF','PEF II','PEM III','PEQ II','PG','PL','PM','PMQ','PMSPP','PPR','PS','PSN','PU','PUM','RFG','SB','SC II','SODM','ST','TAEP','TCCB','TCCF','TCCM I','TCCM II','TCCM III','TCCQ','TG','TSSL','Vib','ZI II','BCB','BCC','BCE','BCT','BF','BFS','BM','BN','BPP','BPT','BQ','BRI','EA','EAU','EIAR','LCB','LF','LFIS','LM','LQ'])
projeto.add_edges_from([('ATRI','BRI'),('AC','BCC'),('AED','BCC'),('Aero I','EA'),('AIMRT','BPT'),('BCE','BFS'),('BC','BCB'),('BD','BCC'),('BECM','BPP'),('Bioquimica','BCB'),('BMT','BM'),('CB','BCE'),('CDD','BPP'),('CGEO','EAU'),('CG','BCC'),('Com I','EA'),('CP','BPP'),('CR','BCC'),('CTS','BPP'),('DA','EA'),('Demo','BPT'),('Din I','EA'),('DRGR','BCE'),('ECA','EA'),('EDP','BCB'),('EDS','BPP'),('EI','LM'),('EP','BCE'),('EPIE','BRI'),('Espec','BQ'),('ET','BPT'),('Ética','BF'),('FA','LF'),('FHAL','BRI'),('FP','BF'),('FPP','BPP'),('FT','LFIS'),('FUV','BM'),('FV II','BCB'),('GPO','BRI'),('GP','BCB'),('GPIR','BRI'),('HAH','EAU'),('HEG','BCE'),('HFC','BF'),('HFME','LF'),('HFMO','BF'),('HTM','BRI'),('IA','BCC'),('IDC','BPP'),('IED','BRI'),('IEDO','BM'),('IN','BN'),('InA','EA'),('IPP','BPP'),('LB','BCC'),('LF II','BFS'),('MacroE II','BCE'),('MF I','BCB'),('MH II','BCB'),('MicroB','BCB'),('MP','BPT'),('MPK','BCE'),('Neuro','BCB'),('OPGM','BPT'),('PE','BCC'),('PEB II','LCB'),('PEBC','BRI'),('PECM','LFIS'),('PEF','LF'),('PEF II','LFIS'),('PEM III','LM'),('PEQ II','LQ'),('PG','BN'),('PL','BPP'),('PM','BCC'),('PMQ','LFIS'),('PMSPP','BPP'),('PPR','BPT'),('PS','BPP'),('PSN','BN'),('PU','BPT'),('PUM','EAU'),('RFG','BPP'),('SB','BCC'),('SC II','EIAR'),('SODM','BRI'),('ST','BPT'),('TAEP','EA'),('TCCB','BCB'),('TCCF','BFS'),('TCCM I','BM'),('TCCM II','BM'),('TCCM III','BM'),('TCCQ','BQ'),('TG','BCC'),('TSSL','EIAR'),('Vib','EA'),('ZI II','BCB'),('BRI','BCE'),('BRI','BPP'),('BRI','BCT'),('BCC','EA'),('BCC','BCT'),('BCC','BCB'),('BCC','EIAR'),('EA','BCC'),('EA','BCT'),('EA','BFS'),('EA','EIAR'),('EA','BM'),('BPT','BCT'),('BPT','BCE'),('BPT','BPP'),('BPT','EAU'),('BPT','LM'),('BPT','BM'),('BCT','BRI'),('BCT','BCC'),('BCT','EA'),('BCT','BPT'),('BCT','BCB'),('BCT','BCE'),('BCT','BPP'),('BCT','EAU'),('BCT','LM'),('BCT','BQ'),('BCT','BF'),('BCT','LF'),('BCT','LFIS'),('BCT','BN'),('BCT','BFS'),('BCT','LCB'),('BCT','LQ'),('BCT','EIAR'),('BCT','BM'),('BCB','BCC'),('BCB','BCT'),('BCB','EAU'),('BCB','BQ'),('BCB','LCB'),('BCB','LQ'),('BCE','BRI'),('BCE','BPT'),('BCE','BCT'),('BCE','BPP'),('BCE','EAU'),('BCE','BM'),('BPP','BRI'),('BPP','BPT'),('BPP','BCT'),('BPP','EAU'),('BPP','BF'),('BPP','LF'),('EAU','BPT'),('EAU','BCT'),('EAU','BCB'),('EAU','BCE'),('EAU','LM'),('EAU','BFS'),('EAU','EIAR'),('EAU','BM'),('LM','BPT'),('LM','BCT'),('LM','EAU'),('LM','LFIS'),('LM','BFS'),('LM','BM'),('BQ','BCT'),('BQ','BCB'),('BQ','BFS'),('BQ','LQ'),('BF','EA'),('BF','BCT'),('BF','BPP'),('BF','LF'),('LF','BCT'),('LF','BPP'),('LF','BF'),('LFIS','BCT'),('LFIS','LM'),('LFIS','BFS'),('LFIS','BM'),('BN','BCT'),('BN','LCB'),('BN','BCB'),('BCB','BN'),('BFS','EA'),('BFS','BCT'),('BFS','EAU'),('BFS','LM'),('BFS','BQ'),('BFS','LFIS'),('BFS','EIAR'),('LCB','BCT'),('LCB','BCB'),('LCB','BN'),('LQ','BCT'),('LQ','BCB'),('LQ','BQ'),('EIAR','BCC'),('EIAR','EA'),('EIAR','BCT'),('EIAR','EAU'),('EIAR','BFS'),('EIAR','BM'),('BM','EA'),('BM','BPT'),('BM','BCT'),('BM','BCE'),('BM','EAU'),('BM','LM'),('BM','LFIS'),('BM','EIAR')])
plt.figure(figsize = (10, 10))
nx.draw(projeto, with_labels=True, node_size=500, node_color='gold', font_weight='bold')

# %%
#Análise 1 - Quais Cursos tiveram a maior quantidade de turmas disponíveis
from networkx.algorithms.cuts import edge_expansion
import networkx as nx
import matplotlib.pyplot as plt

projeto.add_edge("ATRI","BRI",weight=16)
projeto.add_edge("AC","BCC",weight=18)
projeto.add_edge("AED","BCC",weight=8)
projeto.add_edge("Aero I","EA",weight=12)
projeto.add_edge("AIMRT","BPT",weight=24)
projeto.add_edge("BCE","BFS",weight=32)
projeto.add_edge("BC","BCB",weight=8)
projeto.add_edge("BD","BCC",weight=24)
projeto.add_edge("BECM","BPP",weight=2)
projeto.add_edge("Bioquimica","BCB",weight=2)
projeto.add_edge("BMT","BM",weight=4)
projeto.add_edge("CB","BCE",weight=3)
projeto.add_edge("CDD","BPP",weight=3)
projeto.add_edge("CGEO","EAU",weight=6)
projeto.add_edge("CG","BCC",weight=13)
projeto.add_edge("Com I","EA",weight=2)
projeto.add_edge("CP","BPP",weight=3)
projeto.add_edge("CR","BCC",weight=1)
projeto.add_edge("CTS","BPP",weight=2)
projeto.add_edge("DA","EA",weight=1)
projeto.add_edge("Demo","BPT",weight=1)
projeto.add_edge("Din I","EA",weight=2)
projeto.add_edge("DRGR","BCE",weight=2)
projeto.add_edge("ECA","EA",weight=2)
projeto.add_edge("EDP","BCB",weight=2)
projeto.add_edge("EDS","BPP",weight=2)
projeto.add_edge("EI","LM",weight=2)
projeto.add_edge("EP","BCE",weight=1)
projeto.add_edge("EPIE","BRI",weight=2)
projeto.add_edge("Espec","BQ",weight=2)
projeto.add_edge("ET","BPT",weight=2)
projeto.add_edge("Ética","BF",weight=2)
projeto.add_edge("FA","LF",weight=1)
projeto.add_edge("FHAL","BRI",weight=1)
projeto.add_edge("FP","BF",weight=1)
projeto.add_edge("FPP","BPP",weight=1)
projeto.add_edge("FT","LFIS",weight=2)
projeto.add_edge("FUV","BM",weight=2)
projeto.add_edge("FV II","BCB",weight=2)
projeto.add_edge("GPO","BRI",weight=2)
projeto.add_edge("GP","BCB",weight=4)
projeto.add_edge("GPIR","BRI",weight=2)
projeto.add_edge("HAH","EAU",weight=2)
projeto.add_edge("HEG","BCE",weight=2)
projeto.add_edge("HFC","BF",weight=2)
projeto.add_edge("HFME","LF",weight=2)
projeto.add_edge("HFMO","BF",weight=2)
projeto.add_edge("HTM","BRI",weight=2)
projeto.add_edge("IA","BCC",weight=2)
projeto.add_edge("IDC","BPP",weight=2)
projeto.add_edge("IED","BRI",weight=2)
projeto.add_edge("IEDO","BM",weight=2)
projeto.add_edge("IN","BN",weight=2)
projeto.add_edge("InA","EA",weight=2)
projeto.add_edge("IPP","BPP",weight=2)
projeto.add_edge("LB","BCC",weight=2)
projeto.add_edge("LF II","BFS",weight=2)
projeto.add_edge("MacroE II","BCE",weight=2)
projeto.add_edge("MF I","BCB",weight=1)
projeto.add_edge("MH II","BCB",weight=2)
projeto.add_edge("MicroB","BCB",weight=2)
projeto.add_edge("MP","BPT",weight=2)
projeto.add_edge("MPK","BCE",weight=2)
projeto.add_edge("Neuro","BCB",weight=2)
projeto.add_edge("OPGM","BPT",weight=2)
projeto.add_edge("PE","BCC",weight=2)
projeto.add_edge("PEB II","LCB",weight=2)
projeto.add_edge("PEBC","BRI",weight=2)
projeto.add_edge("PECM","LFIS",weight=2)
projeto.add_edge("PEF","LF",weight=2)
projeto.add_edge("PEF II","LFIS",weight=6)
projeto.add_edge("PEM III","LM",weight=2)
projeto.add_edge("PEQ II","LQ",weight=2)
projeto.add_edge("PG","BN",weight=2)
projeto.add_edge("PL","BPP",weight=2)
projeto.add_edge("PM","BCC",weight=1)
projeto.add_edge("PMQ","LFIS",weight=4)
projeto.add_edge("PMSPP","BPP",weight=2)
projeto.add_edge("PPR","BPT",weight=2)
projeto.add_edge("PS","BPP",weight=2)
projeto.add_edge("PSN","BN",weight=1)
projeto.add_edge("PU","BPT",weight=1)
projeto.add_edge("PUM","EAU",weight=2)
projeto.add_edge("RFG","BPP",weight=1)
projeto.add_edge("SB","BCC",weight=2)
projeto.add_edge("SC II","EIAR",weight=1)
projeto.add_edge("SODM","BRI",weight=5)
projeto.add_edge("ST","BPT",weight=3)
projeto.add_edge("TAEP","EA",weight=2)
projeto.add_edge("TCCB","BCB",weight=1)
projeto.add_edge("TCCF","BFS",weight=1)
projeto.add_edge("TCCM I","BM",weight=1)
projeto.add_edge("TCCM II","BM",weight=1)
projeto.add_edge("TCCM III","BM",weight=1)
projeto.add_edge("TCCQ","BQ",weight=1)
projeto.add_edge("TG","BCC",weight=1)
projeto.add_edge("TSSL","EIAR",weight=2)
projeto.add_edge("Vib","EA",weight=1)
projeto.add_edge("ZI II","BCB",weight=1)

pos = nx.spring_layout(projeto);
plt.figure(figsize = (10, 10))
nx.draw(projeto, pos, with_labels=True, font_weight='bold', node_size=600, node_color='gold');
edge_weight = nx.get_edge_attributes(projeto,'weight');
nx.draw_networkx_edge_labels(projeto, pos, edge_labels = edge_weight);

# %%
from networkx.algorithms.bipartite.basic import color
from networkx.algorithms.assortativity.pairs import node_attribute_xy
import networkx as nx

# Ordem
print("Ordem: ", projeto.order())
# Tamanho
print("Tamanho: ", projeto.size())
# Diâmetro
print("Diâmetro: ", nx.diameter(projeto))
# Conectividade de vértices
print("Conectividade de vértices ",nx.node_connectivity(projeto))
# Conectividade de arestas
print("Conectividade de arestas: ",nx.edge_connectivity(projeto))
# Destacando com base na quantidade de vértices
nx.draw(projeto, node_color = [projeto.degree(v) for v in projeto], with_labels=True)

# %%
import networkx as nx
# a) Busca em Largura
S = nx.bfs_tree(projeto, 'BCT')
nx.draw_networkx(S)

# %%
import networkx as nx

cor_vertices = [nx.degree_centrality(projeto)[v] for v in projeto]
tamanho_vertices = [160 + 160 * projeto.degree(v) for v in projeto]

rotulo_vertices = {} 
for v in projeto.nodes(): 
  rotulo_vertices[v] = round(nx.degree_centrality(projeto)[v], 2)

pos = nx.spring_layout(projeto)
print("Centralidade de Grau: ")
nx.draw(projeto, pos, node_size = tamanho_vertices, node_color = cor_vertices)
nx.draw_networkx_labels(projeto, pos, rotulo_vertices, font_weight = 'bold', font_color = 'white' );

# %%
import networkx as nx

cor_vertices = [nx.closeness_centrality(projeto)[v] for v in projeto]
tamanho_vertices = [190 + 190 * projeto.degree(v) for v in projeto]

rotulo_vertices = {} 
for v in projeto.nodes(): 
  rotulo_vertices[v] = round(nx.closeness_centrality(projeto)[v], 2)

print("Centralidade de Proximidade:")
nx.draw(projeto, pos, node_size = tamanho_vertices, node_color = cor_vertices)
nx.draw_networkx_labels(projeto, pos, rotulo_vertices, font_weight = 'bold', font_color = 'white' );
# Out:
# Centralidade de Proximidade:

# %%
import networkx as nx
import matplotlib.pyplot as plt

degrees = [projeto.degree(n) for n in projeto.nodes()]

plt.hist(degrees)
plt.title("Degree Histogram")
plt.ylabel("Count")
plt.xlabel("Degree")
plt.grid(True)

plt.show()

# %% [markdown]
# **IMPORTANTE**:
#
#
# ---
#
# >
# >
# Inicialmente, preencham os dados do **Projeto Prático** na seguinte planilha:
#
# > https://docs.google.com/spreadsheets/d/1grVfQKa6F7QMz7NHK55c9k95wQ_PilGw3VdINQDCU2A/edit?usp=sharing
#
# O **Projeto Prático** deve ser feito usando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook, armazenado no Google Drive, deve ser enviado usando o seguinte formulário:
#
# > https://forms.gle/bxTSECDr3ubLKA2r5
#
# A submissão deve ser feita até o dia **12/05/2022** (quinta-feira - até às 23h59). Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO.
